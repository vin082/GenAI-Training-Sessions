# %% [markdown]
# # Generative AI & Prompt Engineering: A Hands-On Workshop
#
# **Welcome!** 👋
#
# In this interactive session, we'll explore:
# 1. 🤖 **GenAI Overview** - Understanding the technology
# 2. ✍️ **Prompt Engineering** - Communicating effectively with AI
# 3. 🎯 **Context Engineering** - Providing the right information
#
# **Session Goals:**
# - Understand what GenAI is and how it works
# - Learn different prompting techniques
# - Learn to craft effective prompts for real-world tasks
# - Practice with hands-on examples
#
# ---
#
# **💡 Discussion Question:** Before we start, what have you heard about AI? What do you hope to learn today?

# %% [markdown]
# ## Setup: Installing Required Packages
#
# We'll use OpenAI's API for our examples. You can also use Google's Gemini or Anthropic's Claude.

# %%
                                                                                                                                                                                                                                                                                                                                                                                                          # Install required packages (run once)
# !pip install openai python-dotenv google-generativeai huggingface_hub-q

print("✓ Packages installed successfully!")
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (2.8.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.2.1)
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.12/dist-packages (0.8.5)
# ERROR: Could not find a version that satisfies the requirement huggingface_hub-q (from versions: none)
# ERROR: No matching distribution found for huggingface_hub-q
# ✓ Packages installed successfully!

# %% [markdown]
# ### API Key Setup
#
# **For this workshop, you'll need an OpenAI API key:**
# 1. Go to https://platform.openai.com/api-keys
# 2. Sign up or log in
# 3. Create a new API key
# 4. Enter it below (don't share it publicly!)
#
# **Note:** OpenAI charges per API call, but it's very affordable for learning (~$0.002 per request)

# %%
import os
from openai import OpenAI

# Set your API key (replace with your actual key)
# For Colab, you can use userdata to store it securely
try:
    from google.colab import userdata
    OPENAI_API_KEY = userdata.get('OPENAI_API_KEY')
    GEMINI_API_KEY=userdata.get('GEMINI_API_KEY')
except:
    # Or set it directly (not recommended for production)
    OPENAI_API_KEY = "your-api-key-here"
    GEMINI_API_KEY = "your-api-key-here"

os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
client = OpenAI(api_key=OPENAI_API_KEY)
os.environ["GEMINI_API_KEY"] = GEMINI_API_KEY

print("✓ API key configured!")
print(GEMINI_API_KEY)
# Out:
# ✓ API key configured!
# AIzaSyAq-j3OHnC0IYfvYgp29-o0iFnMyH6b6xc

# %% [markdown]
# ### Helper Function: Talk to AI
#
# This simple function will help us send messages to the AI and get responses.

# %%
def ask_ai(prompt, model="gpt-4o-mini", temperature=0.5):
    """
    Send a prompt to OpenAI and get a response.

    Args:
        prompt: Your question or instruction
        model: AI model to use (gpt-4o-mini is fast and cheap)
        temperature: Creativity level (0=focused, 1=creative)
    """
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=temperature
    )
    return response.choices[0].message.content

# Test it!
response = ask_ai("What is GenAI")
print(f"AI says: {response}")
# Out:
# AI says: GenAI, or Generative AI, refers to a class of artificial intelligence models and systems that are capable of generating new content, such as text, images, music, or other data types, based on the patterns and information they have learned from existing datasets. These models use techniques like deep learning, particularly neural networks, to understand and replicate the structure of the data they are trained on.
#
# Some key features of Generative AI include:
#
# 1. **Content Creation**: GenAI can produce original content, such as writing articles, creating artwork, composing music, or generating realistic images.
#
# 2. **Natural Language Processing (NLP)**: In the context of text, models like GPT (Generative Pre-trained Transformer) can generate human-like text, answer questions, summarize information, and engage in conversations.
#
# 3. **Image Generation**: Models like DALL-E and Stable Diffusion can create images from textual descriptions or modify existing images.
#
# 4. **Applications**: Generative AI is used in various fields, including entertainment (e.g., video games, movies), marketing (content generation), design (graphic design), and more.
#
# 5. **Ethical Considerations**: The rise of Generative AI has also raised ethical concerns, such as the potential for creating misleading information, deepfakes, and issues related to copyright and ownership of generated content.
#
# Overall, GenAI represents a significant advancement in AI technology, enabling new forms of creativity and automation across various industries.

# %%
import google.generativeai as genai

def ask_gemini_ai(prompt, model="gemini-2.5-flash", temperature=0.0):
    """
    Send a prompt to Google Gemini and get a response.

    Args:
        prompt: Your question or instruction
        model: Gemini model to use (gemini-2.5-flash is fast and free)
        temperature: Creativity level (0=focused, 1=creative)
    """

    response = genai.GenerativeModel(model).generate_content(
        prompt,
        generation_config=genai.types.GenerationConfig(temperature=temperature)
    )
    return response.text

# Test it!
response = ask_gemini_ai("What is GenAI")
print(f"AI says: {response}")
# Out:
# AI says: **GenAI** stands for **Generative Artificial Intelligence**.
#
# It's a type of artificial intelligence that can **create new, original content** rather than just analyzing or classifying existing data. Unlike traditional AI that might identify a cat in an image (discriminative AI), GenAI can *generate* an entirely new image of a cat based on a text description.
#
# ### How it Works (Simplified)
#
# 1.  **Training on Vast Data:** GenAI models are trained on enormous datasets of text, images, audio, code, or other forms of data. During this training, they learn the underlying patterns, structures, styles, and relationships within that data.
# 2.  **Learning Patterns:** They don't just memorize the data; they learn the "rules" or "grammar" of how that data is constructed. For example, a text-based GenAI learns grammar, syntax, common phrases, and factual information. An image-based GenAI learns about shapes, colors, textures, and how different objects typically appear together.
# 3.  **Generating New Content:** When given a "prompt" (an instruction or input), the model uses these learned patterns to generate something entirely new that is statistically similar to its training data but not a direct copy. It's like a highly skilled mimic or a creative artist who has studied millions of works and can now produce their own in a similar style.
#
# ### Key Characteristics
#
# *   **Creation:** Its primary function is to produce novel outputs.
# *   **Originality:** While inspired by its training data, the output is not a direct copy.
# *   **Versatility:** Can generate various forms of content (text, images, audio, video, code, 3D models, etc.).
# *   **Prompt-driven:** Users interact with it by providing natural language prompts or specific parameters.
# *   **Learning from Data:** Its capabilities are directly tied to the quality and quantity of its training data.
#
# ### Common Types and Examples
#
# *   **Large Language Models (LLMs):** Generate human-like text, answer questions, summarize documents, write code, translate languages.
#     *   *Examples:* ChatGPT (OpenAI), Gemini (Google), Llama (Meta), Claude (Anthropic).
# *   **Image Generators:** Create images from text descriptions (text-to-image), modify existing images, or generate variations.
#     *   *Examples:* DALL-E (OpenAI), Midjourney, Stable Diffusion.
# *   **Music Generators:** Compose melodies, harmonies, or full musical pieces in various styles.
#     *   *Examples:* Amper Music, AIVA.
# *   **Video Generators:** Create short video clips from text prompts or images.
#     *   *Examples:* RunwayML, Pika Labs.
# *   **Code Generators:** Write, complete, or debug programming code.
#     *   *Examples:* GitHub Copilot.
#
# ### Why it's a Big Deal
#
# GenAI is considered a transformative technology because it:
#
# *   **Democratizes Creativity:** Lowers the barrier for individuals to create high-quality content.
# *   **Boosts Productivity:** Automates tasks like writing, design, and coding, freeing up human time for more complex work.
# *   **Unlocks New Possibilities:** Enables the creation of content and experiences that were previously impossible or prohibitively expensive.
# *   **Rapidly Evolving:** The capabilities of GenAI models are advancing at an incredible pace.
#
# ### Challenges and Considerations
#
# Despite its potential, GenAI also presents challenges:
#
# *   **Bias:** Can perpetuate and amplify biases present in its training data.
# *   **Hallucinations:** May generate plausible-sounding but factually incorrect information.
# *   **Copyright and Ownership:** Questions arise about who owns AI-generated content and if it infringes on existing copyrights.
# *   **Misinformation and Deepfakes:** Potential for misuse in creating convincing but false content.
# *   **Job Displacement:** Could impact certain creative and knowledge-based professions.
# *   **Environmental Impact:** Training large models requires significant computational resources and energy.
#
# In summary, GenAI is a powerful and rapidly evolving field that is transforming how we create, interact with, and understand digital content. It's a tool with immense potential, but also one that requires careful consideration of its ethical and societal implications.

# %% [markdown]
# ---
#
# # Part 1: Understanding Generative AI 🤖
#
# ## What is Generative AI?
#
# **Simple Definition:** AI that can create new content (text, images, code, etc.) based on patterns it learned from examples.
#
# **Think of it like this:**
# - A chef who learned from millions of recipes → can create new dishes
# - A writer who read millions of books → can write new stories
# - GenAI learned from the internet → can generate new text, images, code
#
# ## How Does It Work?
#
# **Large Language Models (LLMs)** are trained to:
# 1. **Understand** patterns in language
# 2. **Predict** what comes next
# 3. **Generate** coherent, contextual responses
#
# **Key Insight:** LLMs don't "know" facts - they predict likely responses based on patterns!
#
# ---
#
# ## Popular GenAI Models
#
# | Model | Company | Best For |
# |-------|---------|----------|
# | **GPT-4** | OpenAI | Complex reasoning, coding |
# | **GPT-3.5** | OpenAI | Fast, affordable, general use |
# | **Claude** | Anthropic | Long documents, analysis |
# | **Gemini** | Google | Multimodal (text + images) |
# | **Llama** | Meta | Open-source, local deployment |
#
# ---
#
# **💡 Discussion Question:** What are some tasks you think AI could help with in your work?

# %% [markdown]
# ## GenAI Use Cases
#
# Let's see what GenAI can do with some real examples!

# %% [markdown]
# ### Example 1: Content Writing

# %%
prompt = "Write a professional email announcing a team meeting tomorrow at 2 PM to discuss Q1 goals."

response = ask_ai(prompt)
print("📧 Generated Email:")
print("=" * 60)
print(response)
# Out:
# 📧 Generated Email:
# ============================================================
# Subject: Team Meeting Scheduled for Tomorrow at 2 PM – Discussion on Q1 Goals
#
# Dear Team,
#
# I hope this message finds you well. I would like to invite you to a team meeting scheduled for tomorrow at 2 PM. The primary focus of our discussion will be our goals for the first quarter and how we can align our efforts to achieve them successfully.
#
# Please make it a priority to attend, as your input will be invaluable in shaping our strategies moving forward. If you have any specific topics or concerns you would like to address during the meeting, feel free to share them with me ahead of time.
#
# Looking forward to our discussion!
#
# Best regards,
#
# [Your Name]
# [Your Position]
# [Your Contact Information]

# %% [markdown]
# ### Example 2: Code Generation

# %%
prompt = "Write a Python function that checks if a number is prime."

response = ask_ai(prompt)
print("💻 Generated Code:")
print("=" * 60)
print(response)
# Out:
# 💻 Generated Code:
# ============================================================
# Certainly! Below is a Python function that checks if a given number is prime:
#
# ```python
# def is_prime(n):
#     """Check if a number is prime."""
#     if n <= 1:
#         return False  # Numbers less than or equal to 1 are not prime
#     if n <= 3:
#         return True   # 2 and 3 are prime numbers
#     if n % 2 == 0 or n % 3 == 0:
#         return False  # Eliminate multiples of 2 and 3
#
#     # Check for factors from 5 to the square root of n
#     i = 5
#     while i * i <= n:
#         if n % i == 0 or n % (i + 2) == 0:
#             return False
#         i += 6  # Check for next potential factors (6k ± 1)
#
#     return True  # If no factors were found, n is prime
#
# # Example usage:
# number = 29
# if is_prime(number):
#     print(f"{number} is a prime number.")
# else:
#     print(f"{number} is not a prime number.")
# ```
#
# ### Explanation:
# 1. The function `is_prime(n)` takes an integer `n` as input.
# 2. It first checks if `n` is less than or equal to 1 (not prime) or if it is 2 or 3 (both prime).
# 3. It eliminates even numbers and multiples of 3 quickly.
# 4. For larger numbers, it checks for factors starting from 5 up to the square root of `n`, incrementing by 6 each time (to check only numbers of the form `6k ± 1`).
# 5. If no factors are found, the number is considered prime.
#
# You can test this function with different numbers to check their primality!

# %% [markdown]
# ### Example 3: Data Analysis

# %%
prompt = """Analyze this sales data and provide insights:
Q1: $120,000
Q2: $150,000
Q3: $135,000
Q4: $180,000
"""

response = ask_ai(prompt)
print("📊 Analysis:")
print("=" * 60)
print(response)
# Out:
# 📊 Analysis:
# ============================================================
# Analyzing the provided sales data for each quarter, we can derive several insights:
#
# 1. **Overall Sales Growth**:
#    - The total sales across all four quarters can be calculated as:
#      \[
#      \text{Total Sales} = Q1 + Q2 + Q3 + Q4 = 120,000 + 150,000 + 135,000 + 180,000 = 585,000
#      \]
#    - This indicates a healthy revenue stream for the year.
#
# 2. **Quarterly Growth Comparison**:
#    - **Q1 to Q2**: Sales increased from $120,000 to $150,000, which is a growth of:
#      \[
#      \frac{150,000 - 120,000}{120,000} \times 100 = 25\%
#      \]
#    - **Q2 to Q3**: Sales decreased from $150,000 to $135,000, marking a decline of:
#      \[
#      \frac{135,000 - 150,000}{150,000} \times 100 \approx -10\%
#      \]
#    - **Q3 to Q4**: Sales increased significantly from $135,000 to $180,000, with a growth of:
#      \[
#      \frac{180,000 - 135,000}{135,000} \times 100 \approx 33.33\%
#      \]
#
# 3. **Notable Trends**:
#    - The sales trend shows a strong increase from Q1 to Q2 and a rebound in Q4 after a dip in Q3.
#    - Q4 shows the highest sales, indicating a potential seasonal effect or successful marketing strategies leading up to this quarter, possibly linked to holidays or year-end sales.
#
# 4. **Quarterly Average Sales**:
#    - The average sales per quarter can be calculated as follows:
#      \[
#      \text{Average Sales} = \frac{Total Sales}{4} = \frac{585,000}{4} = 146,250
#      \]
#    - This average indicates that Q2 and Q4 performed above the average, while Q1 and Q3 were below.
#
# 5. **Recommendations for Future Strategy**:
#    - Investigate the factors behind the sales dip in Q3 to understand whether it was seasonal, competitive, or due to operational issues.
#    - Leverage the successful strategies from Q2 and Q4 to maintain or enhance sales performance in Q1 and Q3.
#    - Consider targeting promotions or marketing campaigns during Q3 to mitigate the drop in sales.
#
# 6. **Potential Areas for Focus**:
#    - Further analysis could be conducted on customer demographics, product performance, and external market conditions to better understand the quarterly fluctuations.
#    - Exploring customer feedback from Q3 might uncover insights into the decline and inform strategies to improve sales during that period.
#
# In summary, while the overall performance shows a positive trajectory, addressing the dip in Q3 and capitalizing on successful strategies in Q2 and Q4 will be key to sustaining sales growth in the upcoming periods.

# %% [markdown]
# **💡 Discussion Question:** Which use case is most relevant to your daily work? Can you think of others?

# %% [markdown]
# ## Key Concepts About GenAI
#
# ### 1. **Tokens**
# - AI reads text as "tokens" (roughly 4 characters = 1 token)
# - "Hello world" ≈ 2 tokens
# - Most models have token limits (e.g., 4096, 8192, 128000)
#
# ### 2. **Temperature** (Creativity Dial)
# - **0.0**: Deterministic, factual (same input → same output)
# - **0.7**: Balanced (recommended for most tasks)
# - **1.0+**: Very creative, unpredictable
#
# ### 3. **Context Window**
# - How much text the AI can "remember" at once
# - Think of it as short-term memory
#
# ### 4. **Limitations**
# - ❌ Can "hallucinate" (make up facts)
# - ❌ No real-time knowledge (trained on past data)
# - ❌ Can be biased based on training data

# %% [markdown]
# ### Interactive Demo: Temperature Effect

# %%
prompt = "Write a creative tagline for a coffee shop."

print("Temperature = 0.0 (Predictable):")
print(ask_ai(prompt, temperature=0.0))

print("\nTemperature = 0.7 (Balanced):")
print(ask_ai(prompt, temperature=0.7))

print("\nTemperature = 1.5 (Very Creative):")
print(ask_ai(prompt, temperature=1.5))

# %% [markdown]
# **💡 Discussion Question:** When would you want low vs high temperature? Give examples!

# %% [markdown]
# ---
#
# # Part 2: Prompt Engineering ✍️
#
# ## What is Prompt Engineering?
#
# **Simple Definition:** The art and science of asking AI the right questions in the right way.
#
# **Why It Matters:**
# - Bad prompt → Bad results
# - Good prompt → Excellent results
#
# **Think of AI like a new intern:**
# - 😕 Vague instructions → Confused results
# - 😊 Clear instructions → Great results!
#
# ---
#
# ## Anatomy of a Good Prompt
#
# A well-structured prompt typically has:
#
# 1. **Role/Context**: Who should the AI be?
# 2. **Task**: What do you want?
# 3. **Format**: How should the output look?
# 4. **Constraints**: Any rules or limitations?
# 5. **Examples** (optional): Show, don't just tell!

# %% [markdown]
# ## Technique 1: Zero-Shot Prompting
#
# **What is it?** Asking the AI to do something without any examples.
#
# **When to use:**
# - Simple, common tasks
# - When examples aren't available
# - Quick queries

# %%
# Example: Simple zero-shot
prompt = "Translate 'Hello, how are you?' to French."

response = ask_ai(prompt)
print("Zero-Shot Translation:")
print(response)

# %%
# Example: Classification
prompt = """Classify the sentiment of this review as Positive, Negative, or Neutral:

Review: "The product arrived late but works perfectly."
"""

response = ask_ai(prompt, temperature=0.0)
print("Sentiment:")
print(response)

# %%
# Example: Extract requirements from RFP text
prompt = """Extract and categorize requirements from this RFP excerpt:

"The solution must support at least 10,000 concurrent users with sub-200ms response times.
All data must be encrypted at rest and in transit. The system should integrate with existing
LDAP for authentication. Deployment must be completed within 6 months with zero downtime.
The vendor must provide 24/7 support and maintain SOC2 Type II compliance."

Categorize as: Performance, Security, Integration, Timeline, Support, Compliance
"""

response = ask_ai(prompt, temperature=0.0)
print("📋 Requirement Extraction:")
print(response)

# %%
# Example: Classify modernization approach
prompt = """Classify the recommended modernization strategy for this application:

Application: 10-year-old Java monolith on WebLogic
- Business critical, used daily
- Code quality: Poor, minimal documentation
- Team: Willing to learn new tech
- Timeline: 12 months
- Budget: $1.5M

Classify as one of: Retire, Retain, Rehost (Lift-and-Shift), Replatform, Refactor (Re-architect), Replace

Provide classification with brief justification.
"""

response = ask_ai(prompt, temperature=0.0)
print("🎯 Modernization Strategy:")
print(response)

# %% [markdown]
# ### 👨‍💻 Your Turn: Zero-Shot Exercise

# %%
# TODO: Write a zero-shot prompt to extract information
your_prompt = """
Extract the company name, date, and meeting time from:
"Meeting with Acme Corp on March 15th at 3:30 PM."
"""

response = ask_ai(your_prompt)
print(response)

# %%
# TODO: Write your prompt to summarize this technical spec
your_prompt = """
Summarize the key technical requirements from this specification into 5 bullet points:

[Paste a section from a real RFP you've worked on, or use this example:]

"The proposed system shall provide a web-based interface accessible via modern browsers
(Chrome, Firefox, Safari, Edge). It must support single sign-on via SAML 2.0 and integrate
with the client's existing Active Directory. The backend should be deployed on AWS using
containerized microservices with automatic scaling capabilities. Data persistence must use
PostgreSQL 14+ with automated backups every 6 hours. The solution should implement a RESTful
API with OAuth 2.0 authentication for third-party integrations. All components must be deployed
across multiple availability zones for high availability."
"""

response = ask_ai(your_prompt, temperature=0.0)
print(response)

# %% [markdown]
# ## Technique 2: One-Shot Prompting
#
# **What is it?** Providing ONE example to show the AI what you want.
#
# **When to use:**
# - Task requires specific format
# - Zero-shot results inconsistent

# %%
# Example: Format emails consistently
prompt = """Extract contact info in JSON format.

Example:
Input: "Contact John at john@company.com or 555-1234"
Output: {"name": "John", "email": "john@company.com", "phone": "555-1234"}

Now:
Input: "Reach Sarah Johnson at sarah.j@tech.io, mobile: 555-9876"
Output:
"""

response = ask_ai(prompt, temperature=0.0)
print(response)

# %%
# Example: RFP Requirement → Solution Response Format
prompt = """Convert RFP requirements into solution responses using this format:

Example:
Requirement: "System must handle 50,000 concurrent users"
Response: {
  "requirement_id": "PERF-001",
  "compliance": "Fully Compliant",
  "solution": "Our architecture leverages AWS Auto Scaling Groups with Application Load Balancers to dynamically scale based on demand. Load testing validates capacity for 75,000 concurrent users, exceeding the requirement by 50%.",
  "evidence": "Reference: Project XYZ - 100K concurrent users achieved"
}

Now convert:
Requirement: "All data must be encrypted at rest and in transit with AES-256"
Response:
"""

response = ask_ai(prompt, temperature=0.0)
print("📝 Formatted Response:")
print(response)

# %%
# Example: Convert technical jargon to executive language
prompt = """Convert technical descriptions to executive-friendly language.

Example:
Technical: "We'll implement a CQRS pattern with event sourcing using Kafka for async communication between microservices"
Executive: "We'll use proven architectural patterns that separate read and write operations, improving system performance and enabling real-time data processing."

Now convert:
Technical: "The system utilizes Kubernetes orchestration with Istio service mesh for traffic management, mTLS for inter-service authentication, and Prometheus/Grafana stack for observability"
Executive:
"""

response = ask_ai(prompt, temperature=0.3)
print("💼 Executive Translation:")
print(response)

# %% [markdown]
# ## Technique 3: Few-Shot Prompting
#
# **What is it?** Providing MULTIPLE examples (2-5) to establish a pattern.
#
# **When to use:**
# - Complex tasks
# - When consistency is critical

# %%
# Example: Customer support
prompt = """Generate customer support responses.

Example 1:
Issue: "I can't log in"
Response: "I apologize for the login difficulties. Have you tried resetting your password?"

Example 2:
Issue: "Product is damaged"
Response: "I'm very sorry to hear that. We'll arrange a replacement immediately."

Now:
Issue: "I was charged twice"
Response:
"""

response = ask_ai(prompt, temperature=0.5)
print(response)

# %%
# Example: Compliance matrix responses in your company's style
prompt = """Generate compliance responses following these examples:

Example 1:
Req: "Provide API for third-party integrations"
Response: "✅ COMPLIANT - Our solution exposes a comprehensive RESTful API with OAuth 2.0 authentication. API documentation via Swagger/OpenAPI. Rate limiting: 1000 req/min. SLA: 99.9% uptime. Reference: Successfully integrated with Salesforce, ServiceNow, and SAP for 15+ clients."

Example 2:
Req: "Support mobile access on iOS and Android"
Response: "✅ COMPLIANT - Responsive web design provides optimal mobile experience on all devices. Additionally, native iOS (Swift) and Android (Kotlin) apps available. Supports offline mode with sync. Published on App Store and Google Play. Reference: 4.8★ rating, 50K+ downloads."

Example 3:
Req: "Ensure GDPR compliance for EU customers"
Response: "✅ COMPLIANT - Full GDPR compliance with data residency in EU regions, right-to-deletion workflows, consent management, and automated data portability. Annual third-party GDPR audits. DPO available for consultation. Reference: EU-based clients in Germany, France, Netherlands."

Now generate response for:
Req: "Provide disaster recovery with RPO < 1 hour, RTO < 4 hours"
Response:
"""

response = ask_ai(prompt, temperature=0.3)
print("✅ Compliance Response:")
print(response)

# %%
# TODO: Add 2-3 examples from your actual proposals, then ask AI to generate a new one
your_prompt = """
Generate solution architecture descriptions following our company style:

Example 1:
[Paste example from your proposal]

Example 2:
[Paste another example]

Now generate for:
[New requirement from current RFP]
"""

# response = ask_ai(your_prompt, temperature=0.4)
# print(response)

print("💡 Add your own examples above and uncomment to test")

# %% [markdown]
# ## Technique 4: Chain-of-Thought (CoT)
#
# **What is it?** Asking AI to "think step-by-step" before answering.
#
# **When to use:**
# - Math problems
# - Logical reasoning
# - Complex decisions
#
# **Magic phrase:** "Let's think step by step" or "Analyze this systematically"

# %%
# WITHOUT Chain-of-Thought
prompt = """A store has 15 apples. They sell 8 in the morning,
receive 12 more, then sell 5. How many apples now?"""

print("WITHOUT CoT:")
print(ask_ai(prompt, temperature=0.0))

# %%
# WITH Chain-of-Thought
prompt = """A store has 15 apples. They sell 8 in the morning,
receive 12 more, then sell 5. How many apples now?

Let's think step by step:"""

print("WITH CoT:")
print(ask_ai(prompt, temperature=0.0))

# %%
# Example: Database migration decision
prompt = """Should we recommend migrating from Oracle to PostgreSQL or AWS Aurora?

Context:
- Current: Oracle 19c on-premise, 5TB database
- Workload: 10K transactions/sec peak, heavy analytical queries
- Budget: $500K for database costs (3 years)
- Team: Strong Oracle DBA skills, limited Postgres experience
- Timeline: 9 months for migration
- Client: Risk-averse, prefers proven solutions

Let's analyze this systematically considering:
1. Cost implications
2. Performance compatibility
3. Migration complexity
4. Operational overhead
5. Risk factors
6. Long-term strategic fit
"""

response = ask_ai(prompt, temperature=0.3)
print("🤔 Database Decision Analysis:")
print("=" * 70)
print(response)

# %%
# Example: Containerization approach for legacy app
prompt = """Determine the best containerization approach for this legacy .NET application.

Application Details:
- .NET Framework 4.7.2 (not .NET Core)
- Windows Server 2016 dependencies
- Integrates with COM+ components
- 15 years of legacy code
- Mission-critical (revenue-generating)

Options:
A) Windows Containers (Docker on Windows)
B) Migrate to .NET 6+ then Linux containers
C) Keep on VMs, containerize only new services

Let's think through this step by step:
1. Assess technical feasibility of each option
2. Estimate effort and timeline
3. Consider business risk
4. Evaluate long-term maintainability
5. Calculate cost impact
6. Make recommendation
"""

response = ask_ai(prompt, temperature=0.2)
print("🐳 Containerization Strategy:")
print("=" * 70)
print(response)

# %% [markdown]
# **💡 Discussion:** Notice the difference? CoT shows reasoning!

# %% [markdown]
# ---
#
# # Part 3: Context Engineering 🎯
#
# ## What is Context Engineering?
#
# **Simple Definition:** Providing AI with the right background information.
#
# **Why it matters:**
# - AI doesn't know YOUR situation
# - Better context = Better results
#
# ## The 5 W's of Context:
# 1. **Who** - Who is this for?
# 2. **What** - What exactly do you need?
# 3. **When** - Time constraints?
# 4. **Where** - What domain/industry?
# 5. **Why** - What's the purpose?

# %% [markdown]
# ## Technique 1: Role Assignment

# %%
# Without role
print("WITHOUT Role:")
print(ask_ai("Explain cloud computing."))
print()
# Out:
# WITHOUT Role:
# Cloud computing is a technology that allows individuals and organizations to access, store, and manage data and applications over the internet instead of relying on local servers or personal computers. It provides on-demand availability of computing resources, including servers, storage, databases, networking, software, and more, typically on a pay-as-you-go basis.
#
# ### Key Features of Cloud Computing:
#
# 1. **On-Demand Self-Service**: Users can automatically provision computing resources as needed without requiring human intervention from the service provider.
#
# 2. **Broad Network Access**: Services are available over the network and accessed through standard mechanisms, allowing usage from various devices such as smartphones, tablets, and laptops.
#
# 3. **Resource Pooling**: Providers use a multi-tenant model to serve multiple customers with scalable resources, dynamically assigning and reallocating resources based on demand.
#
# 4. **Rapid Elasticity**: Resources can be scaled up or down quickly, allowing users to adjust their needs according to demand.
#
# 5. **Measured Service**: Cloud systems automatically control and optimize resource usage by leveraging a metering capability, providing transparency for both the provider and the user.
#
# ### Types of Cloud Computing:
#
# 1. **Public Cloud**: Services are delivered over the public internet and shared across multiple organizations. Examples include Amazon Web Services (AWS), Microsoft Azure, and Google Cloud Platform.
#
# 2. **Private Cloud**: Services are dedicated to a single organization, providing more control over data, security, and compliance. Private clouds can be hosted on-premises or by a third-party service provider.
#
# 3. **Hybrid Cloud**: Combines public and private clouds, allowing data and applications to be shared between them. This model provides greater flexibility and more deployment options.
#
# 4. **Community Cloud**: Shared infrastructure for a specific community of users from organizations with common concerns (security, compliance, etc.), managed internally or by a third party.
#
# ### Service Models:
#
# 1. **Infrastructure as a Service (IaaS)**: Provides virtualized computing resources over the internet. Users can rent IT infrastructure such as servers and storage. Example: Amazon EC2.
#
# 2. **Platform as a Service (PaaS)**: Offers a cloud environment for developing, testing, and deploying applications without the complexity of managing the underlying infrastructure. Example: Google App Engine.
#
# 3. **Software as a Service (SaaS)**: Delivers software applications over the internet on a subscription basis, eliminating the need for installation and maintenance. Example: Salesforce, Microsoft 365.
#
# ### Benefits of Cloud Computing:
#
# - **Cost Efficiency**: Reduces the need for physical hardware and associated maintenance costs.
# - **Scalability**: Easily scales resources to meet changing demands.
# - **Accessibility**: Enables access to applications and data from anywhere with an internet connection.
# - **Disaster Recovery**: Provides options for data backup and recovery, enhancing business continuity.
# - **Collaboration**: Facilitates collaboration among teams by enabling simultaneous access to shared applications and documents.
#
# ### Challenges:
#
# - **Security**: Storing sensitive data in the cloud raises concerns regarding privacy and data breaches.
# - **Downtime**: Cloud services can experience outages, affecting accessibility.
# - **Vendor Lock-in**: Difficulty in migrating data and applications from one cloud provider to another can limit flexibility.
# - **Compliance**: Organizations must ensure that cloud services comply with regulatory requirements.
#
# In summary, cloud computing offers a flexible, scalable, and efficient way to manage IT resources and applications, transforming how businesses operate and innovate.

# %%
# With role
prompt = """You are a patient teacher explaining to 10-year-olds.

Explain cloud computing simply."""

print("WITH Role (Teacher):")
print(ask_ai(prompt))
# Out:
# WITH Role (Teacher):
# Sure! Imagine you have a toy box at home where you keep all your favorite toys. But sometimes, your toy box is too full, and there’s no space for new toys.
#
# Now, think of cloud computing like a big toy box in the sky. Instead of keeping everything at home, you can send your toys (or information, like pictures and videos) to this big toy box in the sky. This way, you can access your toys from anywhere, like at a friend’s house or even when you’re on vacation!
#
# When you want to play with your toys, you just need to connect to the internet, and you can see them and use them, just like if they were right there in your room. This big toy box can hold lots of toys, and it doesn’t take up space in your home. Plus, it makes it easy to share toys with your friends!
#
# So, cloud computing is just using the internet to store and use your stuff instead of keeping it all on your own computer. It makes things easier and helps you keep everything safe!

# %% [markdown]
# ## Technique 2: Background Information

# %%
# With rich context
prompt = """Write a product launch email.

Context:
- Company: TechFlow (B2B SaaS)
- Product: FlowSync (project management tool)
- Audience: Existing customers
- Launch: April 1st
- Offer: 20% discount for early adopters
- Tone: Professional but friendly
"""

response = ask_ai(prompt)
print(response)
# Out:
# Subject: Exciting News: Introducing FlowSync – Your New Project Management Companion!
#
# Dear Valued TechFlow Customer,
#
# We hope this message finds you well! We are thrilled to announce the launch of our latest innovation: FlowSync, a state-of-the-art project management tool designed to streamline your workflows and enhance collaboration within your teams.
#
# **Launch Date: April 1st**
#
# FlowSync is built with you in mind, offering powerful features that simplify project planning, tracking, and collaboration. With its intuitive interface and seamless integration capabilities, FlowSync will empower your team to work more efficiently, meet deadlines, and achieve your project goals with ease.
#
# **Key Features of FlowSync:**
# - **Real-Time Collaboration:** Keep your team connected and engaged, no matter where they are.
# - **Customizable Dashboards:** Tailor your project views to match your unique workflow.
# - **Automated Task Management:** Reduce manual effort with intelligent task assignments and reminders.
# - **Comprehensive Reporting:** Gain insights into project performance with detailed analytics.
#
# To celebrate the launch of FlowSync, we are excited to offer our existing customers an exclusive **20% discount** for early adopters. This special offer is available until April 30th, so be sure to secure your access to FlowSync at a reduced rate!
#
# **How to Claim Your Discount:**
# 1. Visit our website and log in to your TechFlow account.
# 2. Select FlowSync from our product offerings.
# 3. Use the promo code EARLYBIRD20 at checkout to enjoy your 20% discount.
#
# We believe FlowSync will be a game-changer for your project management needs, and we can’t wait for you to experience all its benefits. If you have any questions or would like to schedule a demo, please don’t hesitate to reach out to our support team at [support@techflow.com](mailto:support@techflow.com).
#
# Thank you for being a valued member of the TechFlow community. We are excited to help you elevate your project management experience!
#
# Best regards,
#
# [Your Name]
# [Your Title]
# TechFlow Team
# [Contact Information]
# [Website URL]
#
# P.S. Stay tuned for our upcoming webinar where we’ll dive deeper into FlowSync’s features and best practices!

# %% [markdown]
# ## Technique 3: Constraints & Format

# %%
# With constraints
prompt = """Write a product description for eco-friendly water bottle.

Constraints:
- Max 100 words
- Must mention: BPA-free, insulated, 24-hour cold
- Target: Health-conscious millennials
- Tone: Energetic
- Include call-to-action
"""

response = ask_ai(prompt, temperature=0.7)
print(response)
print(f"\nWord count: {len(response.split())}")
# Out:
# Stay refreshed and eco-conscious with our premium insulated water bottle! Made from BPA-free materials, this sleek companion keeps your drinks icy cold for a full 24 hours, perfect for active millennials on-the-go. Whether you’re hitting the gym, hiking trails, or simply conquering your day, our stylish design fits seamlessly into your lifestyle. Make a positive impact on the planet while staying hydrated in style! Don’t wait—grab your eco-friendly water bottle today and elevate your hydration game! 🌍💧
#
# Word count: 77

# %% [markdown]
# ## Technique 4: Output Format

# %%
# JSON format
prompt = """Extract from job posting:
"Senior Python Dev in SF. 5+ years. $120k-$150k. Remote OK. Apply by March 31."

Return as JSON:
{
  "position": "",
  "location": "",
  "experience": "",
  "salary_range": "",
  "remote": true/false,
  "deadline": ""
}"""

print(ask_ai(prompt, temperature=0.0))
# Out:
# ```json
# {
#   "position": "Senior Python Dev",
#   "location": "SF",
#   "experience": "5+ years",
#   "salary_range": "$120k-$150k",
#   "remote": true,
#   "deadline": "March 31"
# }
# ```

# %%
prompt = """You are a senior solution architect with 15 years in application modernization, specializing in cloud-native transformations.

Draft technical approach for RFP Section 3.2:
"Describe your methodology for modernizing our legacy inventory management system (COBOL/CICS) to a cloud-native architecture."

Client Context:
- Industry: Retail (1,200 stores)
- System: 30-year-old COBOL/CICS on mainframe
- Volume: 1M transactions/day, real-time inventory
- Current cost: $2M/year mainframe costs
- Pain points: Slow time-to-market, expensive changes, talent shortage
- Business goal: Launch omnichannel experience within 12 months

Requirements:
- Zero downtime during migration
- Maintain data consistency
- Support peak loads (Black Friday: 5x normal)
- Budget: $3M (including migration)
- Risk-averse stakeholders

Your Response Should Include:
1. Migration approach (phases)
2. Architecture design (high-level)
3. Risk mitigation strategies
4. Technology recommendations
5. Timeline estimate

Format: Professional proposal section
Length: 600-800 words
Tone: Confident, detailed, addresses concerns
"""

response = ask_ai(prompt, temperature=0.4)
print("📄 Technical Approach Section:")
print("=" * 70)
print(response)
print(f"\nWord count: {len(response.split())}")
# Out:
# 📄 Technical Approach Section:
# ======================================================================
# ### Section 3.2: Methodology for Modernizing the Legacy Inventory Management System
#
# #### 1. Migration Approach
#
# To successfully modernize your legacy inventory management system from COBOL/CICS on the mainframe to a cloud-native architecture, we propose a phased migration approach. This approach minimizes risk, ensures zero downtime, and allows for continuous operations throughout the transition. The migration will consist of the following key phases:
#
# **Phase 1: Assessment and Planning**
# - Conduct a comprehensive assessment of the existing COBOL/CICS application, identifying critical functionalities, dependencies, and integration points.
# - Engage stakeholders to gather requirements for the modernized system, focusing on the omnichannel experience.
# - Develop a detailed migration roadmap, including timelines, resource allocation, and budget considerations.
#
# **Phase 2: Design and Prototyping**
# - Design a microservices-based architecture that encapsulates the core functionalities of the legacy system, ensuring scalability and flexibility.
# - Create a prototype for high-priority services to validate the architecture and gather feedback from business users.
#
# **Phase 3: Incremental Migration**
# - Implement an incremental migration strategy, where components are gradually transitioned to the new architecture. This will include:
#   - **Service Decomposition:** Break down the monolithic application into microservices, prioritizing those with the highest transaction volume.
#   - **Data Migration:** Use a hybrid approach to migrate data, ensuring real-time data consistency between the legacy system and the new cloud-native environment.
#   - **API Development:** Create APIs to enable seamless integration between the new microservices and existing systems, facilitating a gradual transition.
#
# **Phase 4: Testing and Validation**
# - Conduct rigorous testing, including unit, integration, and performance testing, to ensure the new system meets functional and non-functional requirements.
# - Validate data consistency and integrity throughout the migration process.
#
# **Phase 5: Go-Live and Support**
# - Execute the final migration with a well-coordinated cutover plan that ensures zero downtime.
# - Provide ongoing support and monitoring to address any issues that may arise post-migration.
#
# #### 2. Architecture Design
#
# The proposed high-level architecture for the cloud-native inventory management system will consist of:
#
# - **Microservices Layer:** Each core functionality (e.g., inventory tracking, order management) will be encapsulated in independent microservices, allowing for independent deployment and scaling.
# - **API Gateway:** An API gateway will manage traffic, enforce security, and facilitate communication between microservices and external systems.
# - **Data Layer:** Utilize a cloud-native database solution (e.g., Amazon RDS, Azure SQL Database) for structured data and a NoSQL solution (e.g., MongoDB, DynamoDB) for unstructured data, ensuring high availability and performance.
# - **Event Streaming:** Implement an event-driven architecture using technologies like Apache Kafka or AWS Kinesis to handle real-time inventory updates and support peak loads.
# - **CI/CD Pipeline:** Establish a Continuous Integration/Continuous Deployment (CI/CD) pipeline to automate testing and deployment, reducing time-to-market for new features.
#
# #### 3. Risk Mitigation Strategies
#
# To address the concerns of risk-averse stakeholders, we will implement the following risk mitigation strategies:
#
# - **Incremental Migration:** By transitioning components gradually, we minimize the impact of potential issues and allow for immediate rollback if needed.
# - **Comprehensive Testing:** Rigorous testing at each stage of the migration will ensure that all functionalities are validated and performance benchmarks are met.
# - **Stakeholder Engagement:** Regular updates and feedback sessions with stakeholders will ensure alignment and transparency throughout the migration process.
# - **Fallback Procedures:** Develop robust fallback procedures to revert to the legacy system if critical issues arise during the go-live phase.
#
# #### 4. Technology Recommendations
#
# To facilitate the migration to a cloud-native architecture, we recommend the following technologies:
#
# - **Cloud Provider:** AWS or Azure for scalable infrastructure and managed services.
# - **Containerization:** Use Docker for packaging microservices and Kubernetes for orchestration, enabling efficient resource management.
# - **Database Solutions:** Amazon RDS for relational data and DynamoDB for high-velocity, unstructured data.
# - **API Management:** Utilize AWS API Gateway or Azure API Management for secure and efficient API management.
# - **Event Streaming:** Implement Apache Kafka or AWS Kinesis for real-time data processing.
#
# #### 5. Timeline Estimate
#
# The estimated timeline for the complete migration is approximately 10 months, broken down as follows:
#
# - **Phase 1: Assessment and Planning (1 month)**
# - **Phase 2: Design and Prototyping (2 months)**
# - **Phase 3: Incremental Migration (5 months)**
# - **Phase 4: Testing and Validation (1 month)**
# - **Phase 5: Go-Live and Support (1 month)**
#
# In summary, our methodology emphasizes a structured, phased approach to modernizing your legacy inventory management system, ensuring zero downtime, maintaining data consistency, and aligning with your business goals. With a focus on minimizing risk and leveraging cloud-native technologies, we are confident that we can deliver a solution that meets your needs and supports your omnichannel strategy within the desired timeframe and budget.
#
# Word count: 749

# %%
prompt = """Create executive talking points for a business case presentation.

Scenario:
Recommending a $4.5M investment in modernizing core banking system

Current State:
- 20-year-old Oracle Forms application
- Hosted in aging data center
- $1.8M annual maintenance
- 3-month release cycles
- Customer complaints about outdated UI
- Compliance challenges (audit trails, reporting)

Proposed Solution:
- Cloud-native web application (React + microservices)
- AWS cloud deployment
- CI/CD with weekly releases
- Modern UX matching competitor capabilities
- Automated compliance reporting

Financial:
- Investment: $4.5M (18 months)
- Annual savings: $900K (infrastructure + maintenance)
- ROI: 5 years
- Risk mitigation: Avoid compliance penalties (potential $2M)

Create:
1. Executive summary (3 sentences)
2. Problem statement (bullet points)
3. Solution overview (bullet points)
4. Business benefits (quantified)
5. Investment & ROI
6. Risk of inaction

Tone: Executive-level, business-focused, compelling
Avoid: Technical jargon
"""

response = ask_ai(prompt, temperature=0.5)
print("💼 Executive Business Case:")
print("=" * 70)
print(response)
# Out:
# 💼 Executive Business Case:
# ======================================================================
# ### Executive Summary
# We propose a strategic investment of $4.5 million to modernize our core banking system, transitioning from a 20-year-old Oracle Forms application to a cloud-native web solution. This modernization will enhance operational efficiency, improve customer satisfaction, and ensure compliance with regulatory standards. By adopting a scalable and agile infrastructure, we can significantly reduce costs and position ourselves competitively in the market.
#
# ### Problem Statement
# - Our current banking system relies on outdated technology, leading to inefficiencies and high maintenance costs of $1.8 million annually.
# - The aging infrastructure is hampering our ability to innovate, with lengthy 3-month release cycles and a user interface that fails to meet customer expectations.
# - We face increasing compliance challenges, risking penalties and reputational damage due to inadequate audit trails and reporting capabilities.
#
# ### Solution Overview
# - Implement a cloud-native web application leveraging modern technologies (React and microservices) to enhance user experience and functionality.
# - Deploy the solution on AWS, ensuring scalability, security, and reduced operational overhead.
# - Establish a Continuous Integration/Continuous Deployment (CI/CD) pipeline to enable weekly releases, fostering innovation and faster time-to-market.
# - Integrate automated compliance reporting to streamline audit processes and ensure regulatory adherence.
#
# ### Business Benefits (Quantified)
# - **Cost Savings**: Annual savings of $900,000 from reduced infrastructure and maintenance costs, leading to a payback period of just over 5 years.
# - **Improved Customer Satisfaction**: A modern user interface will enhance customer experience, potentially increasing customer retention and attracting new clients.
# - **Operational Efficiency**: Faster release cycles will allow us to respond to market demands and regulatory changes more effectively.
# - **Risk Mitigation**: By modernizing our system, we can avoid compliance penalties that could amount to $2 million, safeguarding our financial and reputational standing.
#
# ### Investment & ROI
# - **Total Investment**: $4.5 million over 18 months.
# - **Annual Savings**: $900,000, resulting in a projected ROI of 5 years.
# - **Long-term Value**: Beyond immediate savings, the investment positions us for future growth and innovation.
#
# ### Risk of Inaction
# - Continuing with our outdated system poses significant risks, including escalating maintenance costs, potential compliance violations, and loss of competitive edge.
# - Customer dissatisfaction may lead to churn, adversely affecting our market share and profitability.
# - Failure to modernize could result in missed opportunities for innovation and growth, ultimately jeopardizing our long-term sustainability in an evolving financial landscape.
#
# In summary, this investment is not just a modernization effort; it is a critical step towards securing our future in a competitive and regulated environment.

# %%
prompt = """Create an Architecture Decision Record (ADR) for this decision:

Decision: Choose message queue technology for microservices communication

Options Evaluated:
1. Amazon SQS + SNS
2. Apache Kafka (AWS MSK)
3. RabbitMQ (self-managed)

Context:
- 25 microservices
- Event-driven architecture
- Need: Message ordering, replay capability, audit trail
- Volume: 50K messages/sec peak
- Team: 5 developers, limited Kafka experience
- Preference: Managed services over self-hosting

ADR Format:
## Title
## Status (Proposed/Accepted/Deprecated)
## Context
## Decision
## Consequences (positive and negative)
## Alternatives Considered
"""

response = ask_ai(prompt, temperature=0.2)
print("📋 Architecture Decision Record:")
print("=" * 70)
print(response)
# Out:
# 📋 Architecture Decision Record:
# ======================================================================
# # Architecture Decision Record (ADR)
#
# ## Title
# Choose Message Queue Technology for Microservices Communication
#
# ## Status
# Accepted
#
# ## Context
# Our system architecture consists of 25 microservices that communicate in an event-driven manner. We require a messaging solution that supports message ordering, replay capability, and an audit trail to ensure data integrity and traceability. The expected message volume is significant, with peaks reaching 50,000 messages per second. The development team consists of 5 developers who have limited experience with Kafka. Given the team's preference for managed services to reduce operational overhead, we evaluated three options: Amazon SQS + SNS, Apache Kafka (AWS MSK), and RabbitMQ (self-managed).
#
# ## Decision
# We have decided to adopt **Amazon SQS + SNS** as our message queue technology for microservices communication. This decision is based on the following factors:
#
# 1. **Managed Service**: Amazon SQS and SNS are fully managed services, which reduces the operational burden on our team and allows us to focus on development rather than infrastructure management.
# 2. **Scalability**: SQS can handle high throughput and scales automatically to accommodate our peak load of 50,000 messages per second.
# 3. **Message Ordering**: While SQS does not guarantee strict ordering, FIFO queues can be utilized for scenarios where message order is critical.
# 4. **Replay Capability**: SQS allows for message retention, enabling replay capabilities for up to 14 days, which meets our audit trail requirements.
# 5. **Integration**: SQS and SNS integrate seamlessly with other AWS services, facilitating easier implementation and management of our microservices architecture.
#
# ## Consequences
# ### Positive
# - **Reduced Operational Overhead**: The team can focus on developing features rather than managing infrastructure.
# - **Scalability**: The system can handle high message volumes without manual intervention.
# - **Flexibility**: The combination of SQS and SNS allows for flexible message routing and processing patterns.
# - **Cost-Effective**: Pay-as-you-go pricing model aligns with our budget and usage patterns.
#
# ### Negative
# - **Limited Ordering Guarantees**: While FIFO queues can be used, they may introduce additional complexity and potential performance trade-offs.
# - **Vendor Lock-In**: Relying on AWS services may lead to challenges if we decide to migrate to another cloud provider in the future.
# - **Learning Curve**: The team will need to familiarize themselves with SQS and SNS, which may require some initial investment in training.
#
# ## Alternatives Considered
# 1. **Apache Kafka (AWS MSK)**:
#    - Pros: Strong message ordering, replay capabilities, and high throughput.
#    - Cons: Requires more operational expertise, and the team has limited experience with Kafka. Managed service costs may also be higher than SQS.
#
# 2. **RabbitMQ (self-managed)**:
#    - Pros: Supports complex routing and message patterns, strong community support.
#    - Cons: Requires self-management, which adds operational overhead. Scaling RabbitMQ can be complex, especially at high volumes.
#
# Ultimately, the decision to use Amazon SQS + SNS aligns best with our team's capabilities, operational preferences, and architectural requirements.

# %% [markdown]
# ---
#
# # Key Takeaways
#
# ## Prompt Engineering Techniques
#
# | Technique | When to Use | Key Phrase |
# |-----------|-------------|------------|
# | **Zero-Shot** | Simple tasks | Direct question |
# | **One-Shot** | Specific format | One example |
# | **Few-Shot** | Complex patterns | Multiple examples |
# | **Chain-of-Thought** | Reasoning | "Let's think step by step" |
#
# ## Context Engineering
# - ✅ Assign roles
# - ✅ Provide background
# - ✅ Set constraints
# - ✅ Specify format
#
# ## Golden Rules
# 1. **Be Specific**
# 2. **Provide Context**
# 3. **Show Examples**
# 4. **Set Boundaries**
# 5. **Iterate & Refine**
# 6. **Always Verify**

# %% [markdown]
# ---
#
# # Practice: Your Turn!
#
# Create a prompt for a real task using what you learned.

# %%
# TODO: Write your comprehensive prompt here
my_prompt = """
# Apply the concepts:
# - Choose technique (zero/one/few-shot or CoT)
# - Include role/context
# - Set constraints
# - Specify format


"""

# Test it
response = ask_ai(my_prompt)
print(response)

# %% [markdown]
# ---
#
# # Resources & Next Steps
#
# ## Learn More
# - [OpenAI Prompt Engineering Guide](https://platform.openai.com/docs/guides/prompt-engineering)
# - [Anthropic Prompt Library](https://docs.anthropic.com/claude/prompt-library)
# - [Prompt Engineering Guide](https://www.promptingguide.ai/)
#
# ## Practice Platforms
# - [OpenAI Playground](https://platform.openai.com/playground)
# - [ChatGPT](https://chat.openai.com/)
#
# ## Next Steps
# 1. Practice daily with real tasks
# 2. Build a prompt library
# 3. Experiment with different approaches
# 4. Share and learn from others
#
# ---
#
# # Thank You! 🎉
#
# **Remember:**
# - AI is a tool, not a replacement
# - Good prompts = Good results
# - Practice makes perfect
# - Always verify critical info
#
# **💡 Final Discussion:** What's one task you'll use AI for starting tomorrow?
